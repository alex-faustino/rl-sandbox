# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
env = gym.make('acrobot-v0')
env = env.unwrapped
observation = env.reset()
time = 200
actionlist = np.zeros(time)
theta1list = np.zeros(time)
theta2list = np.zeros(time)
dtheta1list = np.zeros(time)
dtheta2list = np.zeros(time)
rewardlist = np.zeros(time)
t = np.zeros(time)
for i in range(time):
    env.render()
    action=env.action_space.sample() # take a random action
    actionlist[i] = action
    state, reward, endding, info = env.step(action)
    theta1list[i] = state[0]
    theta2list[i] = state[1]
    dtheta1list[i] = state[2]
    dtheta2list[i] = state[3]
    rewardlist[i] = reward
    print('state = {}, reward = {}, terminal = {}, info = {}'.format(state, reward, endding, info))
    t[i] = i

print("Example trajectory")
apic = mpimg.imread('img/acrobot.png')
plt.imshow(apic)
plt.axis('off')
plt.show()

print("Rewards:")
plt.plot(t, rewardlist, 'b')
plt.ylabel('reward')
plt.xlabel('time')
plt.show()
print("We set delta at a reletively high value so every action get reward.")

print("Actions:")
plt.plot(t, actionlist, 'b')
plt.ylabel('torque')
plt.xlabel('time')
plt.show()

print("States:")
plt.plot(t, theta1list, 'b')
plt.plot(t, theta2list, 'r')
plt.ylabel('angle')
plt.xlabel('time')
plt.show()

plt.plot(t, dtheta1list, 'b')
plt.plot(t, dtheta2list, 'r')
plt.ylabel('angular velocity')
plt.xlabel('time')
plt.show()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# False
# state = [-0.00935192  0.04156357 -0.04333718 -0.02074645], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.04229272  0.10066773 -0.27702494  0.59543638], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.11390958  0.26754455 -0.41823303  1.03119332], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.17406657  0.42623843 -0.1683227   0.52412057], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.20293254  0.5349734  -0.11144159  0.54158125], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.2156348   0.63474438 -0.01082296  0.43978842], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.20634108  0.70573022  0.10294109  0.26210964], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.1640544   0.70683732  0.31069332 -0.244496  ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.0873999   0.61380865  0.43921087 -0.66310654], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.01625715  0.42116253  0.5742931  -1.22314042], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.13103734  0.14615577  0.54271831 -1.46371916], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.22027358 -0.13624496  0.3214966  -1.2958967 ], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.22460938 -0.28210655 -0.281117   -0.14166897], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.1122438  -0.19422764 -0.81744072  0.99060117], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.07377818  0.05711844 -0.99671903  1.44798825], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.26586942  0.35015211 -0.87610176  1.40065035], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.39441432  0.55599077 -0.38242751  0.61672434], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.41257281  0.58790866  0.20381548 -0.30179537], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.3409705   0.50459719  0.49668078 -0.51106981], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.20987479  0.36139409  0.78533976 -0.8823589 ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.04136584  0.17226155  0.86006635 -0.95058618], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.10417304  0.04042079  0.56170153 -0.32124349], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.19961754 -0.01267487  0.37213207 -0.18617758], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.2332053   0.00752822 -0.04177823  0.38895388], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.18450032  0.1371434  -0.4309228   0.87647925], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.07016442  0.34010872 -0.68265927  1.0988635 ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.07472523  0.55254426 -0.73179768  0.96913094], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.209049    0.70734877 -0.58258573  0.54027635], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.30964454  0.78811377 -0.4026027   0.24490068], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.36342664  0.79908569 -0.12496034 -0.14179992], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.3577481   0.73162986  0.17957527 -0.52362928], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.27054701  0.53261476  0.67527115 -1.43643002], reward = 1.0, terminal = False, info = {}
# False
# state = [-0