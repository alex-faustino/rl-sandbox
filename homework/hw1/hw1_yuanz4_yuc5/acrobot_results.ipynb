# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
env = gym.make('acrobot-v0')
env = env.unwrapped
observation = env.reset()
time = 200
actionlist = np.zeros(time)
theta1list = np.zeros(time)
theta2list = np.zeros(time)
dtheta1list = np.zeros(time)
dtheta2list = np.zeros(time)
rewardlist = np.zeros(time)
t = np.zeros(time)
for i in range(time):
    env.render()
    action=env.action_space.sample() # take a random action
    actionlist[i] = action
    state, reward, endding, info = env.step(action)
    theta1list[i] = state[0]
    theta2list[i] = state[1]
    dtheta1list[i] = state[2]
    dtheta2list[i] = state[3]
    rewardlist[i] = reward
    print('state = {}, reward = {}, terminal = {}, info = {}'.format(state, reward, endding, info))
    t[i] = i

plt.plot(t, rewardlist, 'b')
plt.ylabel('reward')
plt.xlabel('time')
plt.show()

plt.plot(t, actionlist, 'b')
plt.ylabel('torque')
plt.xlabel('time')
plt.show()

plt.plot(t, theta1list, 'b')
plt.plot(t, theta2list, 'r')
plt.ylabel('angle')
plt.xlabel('time')
plt.show()

plt.plot(t, dtheta1list, 'b')
plt.plot(t, dtheta2list, 'r')
plt.ylabel('angular velocity')
plt.xlabel('time')
plt.show()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# False
# state = [-0.01681962  0.07245837  0.11377851 -0.10406633], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.01825041  0.11258085 -0.126       0.49713702], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.06371403  0.26247701 -0.3134791   0.96668164], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.10995849  0.4144265  -0.13671048  0.52369053], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.14062464  0.53006346 -0.16033325  0.60918845], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.17014497  0.64846649 -0.12632246  0.5532647 ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.18823867  0.74369948 -0.04971638  0.38444341], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.17723354  0.76708596  0.15698902 -0.15063446], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.12807321  0.68645387  0.32426667 -0.63996977], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.0407593   0.48844781  0.53043023 -1.30517051], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.07395031  0.18495745  0.58549099 -1.66349171], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.17892144 -0.14528173  0.43003245 -1.56145697], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.20826657 -0.34420241 -0.14534216 -0.39606485], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.12292537 -0.30105919 -0.68923838  0.80884549], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.0418657  -0.0720714  -0.91875248  1.41684483], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.2256025   0.23301338 -0.87077948  1.54890474], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.35907038  0.48149237 -0.433248    0.88280109], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.39119357  0.57287002  0.11814757  0.01794544], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.33833917  0.55420813  0.40003464 -0.19619978], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.22516783  0.46763483  0.70778041 -0.64325233], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.06770764  0.31240173  0.83109842 -0.86077349], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.07842069  0.17983737  0.59624369 -0.41737797], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.18603563  0.09152018  0.45559386 -0.43365644], reward = 1.0, terminal = False, info = {}
# False
# state = [0.23884699 0.0526126  0.06126229 0.05873669], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.20961719  0.11513344 -0.34532741  0.55045912], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.10769116  0.26067209 -0.64846626  0.86249147], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.03693194  0.43929643 -0.76323372  0.87018789], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.18321999  0.58763632 -0.66719548  0.56993349], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.30431051  0.68509083 -0.51815024  0.37535115], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.38177906  0.72868165 -0.24144856  0.04725596], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.39713071  0.70157541  0.0899917  -0.31570422], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.32312991  0.5424932   0.63549756 -1.25101603], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.16668935  0.25287795  0.89005374 -1.57680161], reward = 1.0, terminal = False, info = {}
# False
# state = [ 8.28867236e-04 -2.02114144e-02  7.41306380e-01 -1.07680394e+00], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.12780171 -0.18655579  0.4981959  -0.53947118], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.19070764 -0.22274051  0.1178028   0.19137271], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0
reward = 1.0, terminal = False, info = {}
# False
# state = [-0.31204828  0.21864136 -0.74131885  2.68370845], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.42865173  0.73986795 -0.37524346  2.41628097], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.43917549  1.12471068  0.26908498  1.40387718], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.33803834  1.32616382  0.71538394  0.61491068], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.14974524  1.32531203  1.11874556 -0.59042285], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.08933052  1.10661259  1.22582482 -1.54800928], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.30072527  0.7896558   0.8453482  -1.54611004], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.42483855  0.48537353  0.36949053 -1.43823858], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.44057963  0.23515432 -0.22103309 -1.02653695], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.32367714  0.11896086 -0.92965121 -0.13593796], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.08283743  0.17048919 -1.42785005  0.59977098], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.20878985  0.29581939 -1.42453629  0.58331199], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.44929171  0.34495977 -0.93378825 -0.12686635], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.59511435  0.30679247 -0.5030217  -0.25848478], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.61871507  0.17439285  0.26620209 -1.04620126], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.52132814 -0.02787357  0.68426742 -0.93211473], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.3305405  -0.24715166  1.18102489 -1.19319683], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.09644518 -0.40539313  1.10847614 -0.32568772], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.1055071  -0.39068543  0.8674242   0.50369071], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.22294647 -0.16532138  0.29030645  1.72747428], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.23711529  0.24227371 -0.12511701  2.26294601], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.19766537  0.66937381 -0.25026583  1.94126042], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.12995141  1.03103215 -0.41684066  1.63819702], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.0343312   1.31360297 -0.52974314  1.1653946 ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.08594031  1.5144387  -0.6529231   0.8162291 ], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.21715724  1.62925024 -0.63293881  0.30644812], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.31019584  1.5786633  -0.26883247 -0.83325047], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.32316821  1.31339649  0.15751934 -1.83002683], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.23184169  0.81764805  0.75502255 -3.11123535], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.03412876  0.09844884  1.14390608 -3.91619363], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.18011675 -0.65369095  0.90268638 -3.40290185], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.28367783 -1.15728162  0.13727163 -1.62337438], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.2628562  -1.36321362 -0.3260456  -0.44642386], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.1533637  -1.31568702 -0.74377181  0.90449595], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.0149708  -1.03655094 -0.91583278  1.85833139], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.22655448 -0.52656338 -1.17372105  3.18921561], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.44918004  0.15789582 -0.96907068  3.47711549], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.56645531  0.75725836 -0.15540642  2.40477921], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.51658185  1.12715393  0.64404381  1.26739069], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.33109438  1.28983509  1.16730152  0.37050041], reward = 1.0, terminal = False, info = {}
# False
# state = [-0.05402898  1.23410584  1.53465406 -0.87725686], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.25507149  0.96537721  1.49444636 -1.73310864], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.52109645  0.57614466  1.11713106 -2.06878781], reward = 1.0, terminal = False, info = {}
# False
# state = [ 0.65803857  0.2420881   0.21857111 -1.19600707], reward = 1.0, terminal = False, info = {}

# %% [markdown]
# Example trajectory:

# %%
# %%html
# <img src = "img/acrobot.png", width = 200, height = 200>
# Out:
# <img src = "img/acrobot.png", width = 200, height = 200>

# %% [markdown]
# States:

# %%
# %%html
# <img src = "img/angle.png", width = 200, height = 200>
# %%html
# <img src = "img/angular velocity.png", width = 200, height = 200>
# Out:
# <img src = "img/angle.png", width = 200, height = 200>
# %%html
# <img src = "img/angular velocity.png", width = 200, height = 200>

# %% [markdown]
# Actions:

# %%
# %%html
# <img src = "img/torque.png", width = 200, height = 200>
# Out:
# <img src = "img/torque.png", width = 200, height = 200>

# %% [markdown]
# Rewards:

# %%
# %%html
# <img src = "img/reward.png", width = 200, height = 200>
# Out:
# <img src = "img/reward.png", width = 200, height = 200>

# %% [markdown]
# We set delta at a reletively high value so all actions get reward.
