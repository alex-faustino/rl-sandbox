# %% [markdown]
# # HW3B - Implement DQN on a pendulum and then on acrobot
# ## Acrobot and Cartpole Environments
# ### Acrobot

# %%
import gym
env = gym.make('Acrobot-v1')
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ### CartPole Environment

# %%
import gym
env = gym.make('CartPole-v0')
env.reset()cart
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action

# %%
from gym import envs
print(envs.registry.all())
# Out:
# dict_values([EnvSpec(StarGunner-v0), EnvSpec(EnduroNoFrameskip-v4), EnvSpec(UpNDown-ram-v4), EnvSpec(Atlantis-ram-v0), EnvSpec(StarGunner-ramDeterministic-v0), EnvSpec(ChopperCommand-v4), EnvSpec(Carnival-ramDeterministic-v4), EnvSpec(TennisNoFrameskip-v0), EnvSpec(FetchReachDense-v1), EnvSpec(AmidarNoFrameskip-v0), EnvSpec(AirRaid-v0), EnvSpec(Asteroids-ramNoFrameskip-v0), EnvSpec(TimePilot-v0), EnvSpec(Amidar-ramNoFrameskip-v4), EnvSpec(Bowling-v0), EnvSpec(GuessingGame-v0), EnvSpec(NChain-v0), EnvSpec(Gravitar-ramDeterministic-v0), EnvSpec(TennisDeterministic-v4), EnvSpec(HandManipulateBlockRotateXYZ-v0), EnvSpec(Seaquest-ram-v0), EnvSpec(ElevatorAction-ramNoFrameskip-v0), EnvSpec(Assault-v4), EnvSpec(AirRaid-ram-v4), EnvSpec(BreakoutNoFrameskip-v0), EnvSpec(Jamesbond-v4), EnvSpec(CubeCrashScreenBecomesBlack-v0), EnvSpec(ChopperCommand-ram-v0), EnvSpec(YarsRevenge-v0), EnvSpec(Jamesbond-ramNoFrameskip-v0), EnvSpec(Carnival-v4), EnvSpec(VideoPinball-ramDeterministic-v4), EnvSpec(Ro
# ...

# %% [markdown]
# # Externally sourced documentation for open ai gym
# ## good introductory blogpost
# In this [blogpost](https://www.oreilly.com/learning/introduction-to-reinforcement-learning-and-openai-gym), it is shown how to:
# * install open ai gym (although this step is sufficiently described on the open ai gym's "documentation" page)
# * read the number of states and actions in an environment.
#
# ## sourcing action and observation
# Given the insufficiency of open ai gym documentation, the following example was sourced from [here](https://katefvision.github.io/10703_openai_gym_recitation.pdf).

# %%
import gym
env = gym.make("Taxi-v2")
observation = env.reset()
for _ in range(1000):
    env.render()
# your agent here (this takes random actions)
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        env.render()
break
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# ...

# %% [markdown]
# ## Inserting sourced actions and observations into example script for acrobot and cartpole
# ### Acrobot

# %%
import gym
env = gym.make('Acrobot-v1')
env.reset()
#print(env.action_space.n)#only works for environments with discrete actions
#print(env.observation_space.n)#only works for environments with discrete state space
#env.observation_space.high
#env.observation_space.low
for _ in range(1000):
    env.render()
    action = env.action_space.sample() # take a random action
    print(action)
    observation, reward, done, info = env.step(action)
#    print([observation,reward,done])
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# 2
# 0
# 2
# 1
# 1
# 0
# 1
# 0
# 1
# 0
# 0
# 2
# 1
# 2
# 1
# 1
# 1
# 2
# 2
# 2
# 1
# 0
# 1
# 1
# 0
# 1
# 2
# 2
# 2
# 2
# 0
# 2
# 1
# 1
# 2
# 0
# 1
# 0
# 0
# 2
# 2
# 1
# 0
# 0
# 2
# 0
# 1
# 2
# 0
# 0
# 2
# 2
# 2
# 0
# 2
# 1
# 0
# 0
# 2
# 0
# 1
# 1
# 0
# 2
# 2
# 1
# 0
# 0
# 1
# 1
# 1
# 0
# 1
# 1
# 2
# 1
# 0
# 0
# 0
# 1
# 0
# 0
# 1
# 1
# 2
# 2
# 0
# 0
# 1
# 0
# 2
# 1
# 2
# 0
# 2
# 0
# 0
# 2
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 2
# 2
# 1
# 0
# 1
# 1
# 2
# 2
# 0
# 0
# 2
# 0
# 0
# 1
# 2
# 0
# 1
# 1
# 2
# 2
# 2
# 0
# 0
# 2
# 1
# 1
# 2
# 0
# 2
# 2
# 0
# 1
# 1
# 1
# 2
# 2
# 1
# 2
# 1
# 1
# 2
# 1
# 0
# 1
# 0
# 0
# 1
# 1
# 2
# 0
# 2
# 1
# 0
# 1
# 2
# 2
# 2
# 1
# 1
# 2
# 0
# 0
# 1
# 2
# 0
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 1
# 2
# 2
# 2
# 1
# 1
# 0
# 0
# 2
# 1
# 0
# 2
# 1
# 1
# 2
# 0
# 2
# 0
# 0
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 0
# 1
# 1
# 2
# 1
# 1
# 2
# 1
# 1
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 0
# 1
# 2
# ...

# %% [markdown]
# ### Cartpole

# %%
import gym
env = gym.make('CartPole-v0')
env.reset()
print(env.observation_space.shape[0])
for _ in range(1000):
    env.render()
#    action = env.action_space.sample() # take a random action
#    print(action)
    observation, reward, done, info = env.step(0)
#    print([observation,reward,done])
# Out:
# 4
# WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.

# %% [markdown]
# # For restarting kernel

# %%
import os
os._exit(00)
