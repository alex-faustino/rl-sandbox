# %%
# %matplotlib inline
import numpy as np
import importlib
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import gym
import policy 
import ppo
Policy = importlib.reload(policy).Policy
PPO = importlib.reload(ppo).PPO

#import seaborn as sns

# %%
env = gym.make('Pendulum-v0')
policy = Policy()
ppo = PPO(env, policy)

rewards, losses = ppo.train(num_episode=100)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
losses
# Out:
# tensor([[7.7070e+02, 6.6735e+01, 1.4573e+02, 1.0624e+02, 4.6575e+02],
#         [6.0703e+04, 2.7020e+04, 8.9551e+02, 8.6628e+02, 7.3222e+02],
#         [5.3168e+04, 2.5242e+05, 6.5845e+05, 3.9825e+04, 2.6468e+04],
#         [9.6966e+02, 9.8675e+02, 3.2406e+02, 1.4835e+02, 3.3090e+02],
#         [1.1647e+03, 1.5624e+03, 1.9968e+03, 2.5763e+03, 3.7720e+03],
#         [1.5199e+03, 2.4444e+03, 2.3304e+03, 1.7983e+03, 8.9991e+02],
#         [2.5716e+01, 2.7393e+02, 9.4737e+01, 2.1194e+02, 3.6520e+02],
#         [4.9389e+02, 2.7998e+02, 4.3286e+02, 3.3131e+02, 3.2931e+03],
#         [1.2630e+03, 1.4119e+03, 1.2225e+03, 5.4345e+02, 3.0992e+02],
#         [1.6043e+03, 2.2948e+03, 1.9971e+03, 9.9111e+02, 2.2812e+02],
#         [5.0464e+02, 6.2701e+02, 4.0618e+02, 3.7311e+02, 2.9521e+02],
#         [1.3323e+04, 1.1344e+04, 1.2273e+03, 4.9343e+05, 1.9470e+07],
#         [6.0715e+06, 2.3719e+06, 9.9024e+05, 4.6740e+05, 7.0411e+04],
# ...

# %%
rewards
# Out:
# tensor([-713.7069, -735.0126, -641.6409, -806.7764, -717.8240, -749.3788,
#         -609.4890, -799.8400, -737.7853, -752.8680, -670.3774, -457.9582,
#         -749.9800, -793.2443, -712.5261, -818.6997, -663.9236, -601.9783,
#         -761.6295, -798.7562, -789.8116, -819.3347, -720.0161, -748.6446,
#         -746.7741, -790.3860, -805.8819, -782.9198, -743.8254, -746.4557,
#         -688.5786, -605.2538, -706.5925, -814.9338, -666.3284, -812.0428,
#         -814.6974, -539.9785, -758.3323, -503.0485, -620.1655, -814.2905,
#         -470.4733, -600.2383, -740.5712, -746.4503, -748.6460, -673.3914,
#         -679.9521, -739.1287, -375.6647, -746.5042, -762.9333, -750.5965,
#         -740.1418, -776.3168, -807.0485, -801.4889, -811.6752, -660.4758,
#         -820.4111, -746.1956, -820.1753, -695.5102, -748.9700, -728.3381,
#         -814.9394, -800.6799, -700.1704, -795.9897, -675.9504, -683.4680,
#         -519.0951, -746.0131, -815.0758, -573.4626, -747.2750, -808.2292,
# ...

# %%
plt.plot(rewards.detach().numpy())

# %%
plt.plot(losses.sum(dim=1).detach().numpy()[1:10])

# %%
# Out:
# tensor([1.5552e+03, 9.0217e+04, 1.0303e+06, 2.7597e+03, 1.1072e+04, 8.9929e+03,
#         9.7151e+02, 4.8311e+03, 4.7507e+03, 7.1154e+03, 2.2062e+03, 1.9989e+07,
#         9.9715e+06, 4.0836e+04, 5.3644e+07, 2.2236e+07, 2.5388e+07, 1.5290e+06,
#         2.5379e+07, 6.5441e+06, 8.8531e+08, 1.4414e+08, 1.1034e+07, 1.3823e+06,
#         1.7312e+06, 1.8220e+07, 2.0193e+06, 1.0292e+05, 1.6727e+04, 9.0021e+02,
#         1.1519e+03, 4.3210e+03, 1.2242e+04, 1.0083e+11, 4.3583e+10, 3.0593e+10,
#         5.0499e+11, 1.7504e+08, 2.7544e+06, 3.7001e+03, 2.5843e+03, 4.0106e+03,
#         2.2229e+03, 2.3454e+03, 2.4167e+03, 2.5097e+03, 3.9190e+03, 3.7355e+03,
#         4.0490e+03, 4.1709e+03, 2.4593e+03, 2.5903e+03, 4.4482e+03, 4.3012e+03,
#         4.1790e+03, 4.8528e+03, 3.9958e+03, 4.6324e+03, 4.1838e+03, 3.3650e+03,
#         3.8092e+03, 2.7937e+03, 3.7984e+03, 3.7650e+03, 2.6141e+03, 1.8548e+03,
#         3.7842e+03, 4.0534e+03, 3.7131e+03, 4.7769e+03, 3.3095e+03, 3.7115e+03,
# ...
