# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# File Name of Results file
file_name = 'hw6_PPO_Pendulum_v1' 

with open(file_name, 'rb') as file:
    AvgReward = pickle.load(file)
    
plt.plot(AvgReward)
plt.grid(axis='both')
plt.xlabel('Epochs')
plt.ylabel('Avg Reward')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
