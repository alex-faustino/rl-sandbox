# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# File Name of Results file
file_name = 'hw6_PPO_Pendulum_v1' 

with open(file_name, 'rb') as file:
    AvgReward = pickle.load(file)
    
plt.plot(AvgReward)
plt.grid(axis='both')
plt.xlabel('Epochs')
plt.ylabel('Avg Reward')
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-df63c6e39acc> in <module>()
#      12 plt.grid(axis='both')
#      13 plt.xlabel('Epochs')
# ---> 14 plt.yalabel('Avg Reward')
#      15 plt.show
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'yalabel'
