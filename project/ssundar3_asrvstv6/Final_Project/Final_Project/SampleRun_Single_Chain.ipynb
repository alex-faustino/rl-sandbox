# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Dec 10 20:04:28 2018

@author: baranwa2
"""
import numpy as np
import importlib, random
import matplotlib.pyplot as plt
import gym_env
import gym

import sarsa
sarsa = importlib.reload(sarsa)
import Risca
Risca = importlib.reload(Risca)
import single_chain_class_version
single_chain_class_version = importlib.reload(single_chain_class_version)
import Reinforce
Reinforce = importlib.reload(Reinforce)

#Creating object of Sarsa class and passing environment
env = gym.make('single_chain-v0')
sarsa_agent = sarsa.SarsaAgent(env)

#-----------------SARSA Parametrs-----------
epsilon = 1
alpha = 0.1
gamma = 0.9
episode_max_length = 1000
num_episodes = 10
#count_var = int(num_episodes/500)
#new_var = count_var+1
tot_reward_sarsa = np.zeros((5,num_episodes))
episode_50 = [i for i in range(num_episodes)]
#np.random.seed(0)

#------------REPS Parameters--------------------
#features = [[1, 0, 0], [1, 1, 1], [1, 2, 4], [1, 3, 9], [1, 4, 16]]
features = [[1, 0, 0], [1, 1, 1], [1, 2, 4], [1, 3, 9]]

features = np.array(features)

theta0 = np.dot(10,np.random.random_sample(features[0].shape[0]))
eta0 = 10
x0 = np.append(theta0, eta0)
epsilon_r = 1

#R = np.array([[0, 0], [0, 2], [0, 2], [0, 2], [10, 2]])
R = np.array([[0, 0], [0, 2], [0, 2], [10, 2]])
info_loss=0.5
n_policy_updates=10
n_samples=500
opt_method='L-BFGS-B'
tot_reward_reps = np.zeros((5,n_policy_updates))
episode_reps = [i for i in range(n_policy_updates)]

#----Policy Gradient Parameters----------
reinforce_agent = Reinforce.ReinforceAgent(env)
risca_agent = Risca.ReinforceCis(env)
alphan = 0.01
ep_max = 25
epsilonn = 0
t_steps = 40
episodes = 10
tot_reward_reinforce = np.zeros((5,episodes))
#episode_reps = [i for i in range(n_policy_updates)]
tot_reward_risca = np.zeros((5,episodes))

for item in range(5):
    rewards_sarsa = []
    rewards_reinforce = []
    rewards_risca = []
    rewards_reps = []
    policy = single_chain_class_version.Policy_REPS(env)
    agent = single_chain_class_version.run_REPS()
    rewards_sarsa = sarsa_agent.train(epsilon, alpha, gamma, episode_max_length, num_episodes)
    rewards_reps, V, policy, q_sa, theta, eta = agent.REPS(env, R, policy, features, x0, epsilon_r, info_loss,
                                      n_policy_updates, n_samples, opt_method)
    rewards_sarsa/= episode_max_length
    rewards_risca = risca_agent.train(alphan,ep_max,epsilonn,t_steps,episodes)
    rewards_reinforce = reinforce_agent.train(alphan,ep_max,epsilonn,t_steps,episodes)
    tot_reward_sarsa[item,:] = rewards_sarsa
    tot_reward_reps[item,:] = rewards_reps
    tot_reward_reinforce[item,:] = rewards_reinforce
    tot_reward_risca[item,:] = rewards_risca
    

mean1 = np.mean(tot_reward_sarsa, axis=0)
mean2 = np.mean(tot_reward_reps, axis=0)
mean3 = np.mean(tot_reward_reinforce, axis=0)
mean4 = np.mean(tot_reward_risca, axis=0)
#mean1[0] = np.amin(tot_reward[:,0])
green_point = dict(markerfacecolor='g', marker='D')
print('---SARSA_Means----')
print(mean1)
print(len(episode_50))
print('---REPS_Means---')
print(mean2)
print(len(episode_50))
print('---REINFORCE_Means---')
print(mean3)
print(len(episode_50))
print('---REINFORCE+IS+Causality_Means---')
print(mean4)
print(len(episode_50))

#Set_up for the plots
plt.figure(1)
plt.boxplot(tot_reward_sarsa,positions = episode_50 , showmeans = True)
line1, = plt.plot(episode_50,mean1,'b')
plt.boxplot(tot_reward_reps,positions = episode_50 , showmeans = True)
line2, = plt.plot(episode_50,mean2,'r')
plt.boxplot(tot_reward_reinforce,positions = episode_50 , showmeans = True)
line3, = plt.plot(episode_50,mean3,'c')
plt.boxplot(tot_reward_risca,positions = episode_50 , showmeans = True)
line4, = plt.plot(episode_50,mean4,'k')
plt.title('Performance of various algorithms on Two State environment')
plt.xlabel('Policy Updates')
plt.ylabel('Average Reward')
label_line = ['SARSA','REPS','REINFORCE','REINFORCE_IS_CA']
plt.legend([line1,line2,line3,line4], label_line)
plt.show()
# Out:
# #################################################
#
# Policy update 1/10 -
# dual value optim :  5.120682462076758
# dual gradient theta :  0.42004525193113
# dual gradient eta :  2.0187161420966033
# KL Divergence:  1.207848688550032
# J: 9.63; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.967741579769796
# Policy :
#  [[0.622 0.378]
#  [0.662 0.338]
#  [0.928 0.072]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 2/10 -
# dual value optim :  10.743900122921636
# dual gradient theta :  0.0005049554602386985
# dual gradient eta :  0.12567164568223
# KL Divergence:  0.15083525837627254
# J: 9.74; b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.753 0.247]
#  [0.819 0.181]
#  [0.993 0.007]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 3/10 -
# dual value optim :  10.78533106483157
# dual gradient theta :  0.0001898684309802374
# dual gradient eta :  0.12598271162834962
# KL Divergence:  0.004958894975667895
# J: 9.75; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.753 0.247]
#  [0.819 0.181]
#  [0.999 0.001]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 4/10 -
# dual value optim :  10.78533106483157
# dual gradient theta :  0.0001898684309802374
# dual gradient eta :  0.12598271162834962
# KL Divergence:  0.0004721902528226704
# J: 9.77; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.753 0.247]
#  [0.819 0.181]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 5/10 -
# dual value optim :  10.78533106483157
# dual gradient theta :  0.0001898684309802374
# dual gradient eta :  0.12598271162834962
# KL Divergence:  4.47762914295061e-05
# J: 9.77; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.753 0.247]
#  [0.819 0.181]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 6/10 -
# dual value optim :  10.78533106483157
# dual gradient theta :  0.0001898684309802374
# dual gradient eta :  0.12598271162834962
# KL Divergence:  4.244317073391565e-06
# J: 9.75; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.753 0.247]
#  [0.819 0.181]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 7/10 -
# dual value optim :  10.779033637790869
# dual gradient theta :  0.00024784714045527316
# dual gradient eta :  0.12591040611678306
# KL Divergence:  0.10820172541436768
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.85  0.15 ]
#  [0.953 0.047]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 8/10 -
# dual value optim :  10.78533106483157
# dual gradient theta :  0.0001898684309802374
# dual gradient eta :  0.12598271162834962
# KL Divergence:  3.813231486871099e-08
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.85  0.15 ]
#  [0.953 0.047]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 9/10 -
# dual value optim :  10.779033637790869
# dual gradient theta :  0.00024784714045527316
# dual gradient eta :  0.12591040611678306
# KL Divergence:  0.03890857888981396
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.913 0.087]
#  [0.989 0.011]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 10/10 -
# dual value optim :  10.779033637790869
# dual gradient theta :  0.00024784714045527316
# dual gradient eta :  0.12591040611678306
# KL Divergence:  0.015627249134773792
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5768584444798672
# Policy :
#  [[0.951 0.049]
#  [0.997 0.003]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 1/10 -
# dual value optim :  6.617637526936836
# dual gradient theta :  0.32638728316277865
# dual gradient eta :  1.751337201402488
# KL Divergence:  1.407465563114523
# J: 9.70; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 2.0304060357829936
# Policy :
#  [[0.646 0.354]
#  [0.745 0.255]
#  [0.967 0.033]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 2/10 -
# dual value optim :  10.7752378019503
# dual gradient theta :  0.00042476666022458435
# dual gradient eta :  0.15733808326544452
# KL Divergence:  0.23335854310152546
# J: 9.78; b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.799 0.201]
#  [0.95  0.05 ]
#  [0.998 0.002]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 3/10 -
# dual value optim :  10.772079230539257
# dual gradient theta :  0.0004218750986280611
# dual gradient eta :  0.15736144708187183
# KL Divergence:  0.0642530332778653
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.897 0.103]
#  [0.992 0.008]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 4/10 -
# dual value optim :  10.781491747356784
# dual gradient theta :  0.0003437066045513592
# dual gradient eta :  0.1574418504299402
# KL Divergence:  1.756974658251103e-05
# J: 9.81; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.897 0.103]
#  [0.992 0.008]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 5/10 -
# dual value optim :  10.7752378019503
# dual gradient theta :  0.00042476666022458435
# dual gradient eta :  0.15733808326544452
# KL Divergence:  0.022862457273359275
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.95  0.05 ]
#  [0.999 0.001]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 6/10 -
# dual value optim :  10.7752378019503
# dual gradient theta :  0.00042476666022458435
# dual gradient eta :  0.15733808326544452
# KL Divergence:  0.00977899562142351
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.976 0.024]
#  [1.    0.   ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 7/10 -
# dual value optim :  10.781491747356784
# dual gradient theta :  0.0003437066045513592
# dual gradient eta :  0.1574418504299402
# KL Divergence:  2.2942413667770407e-09
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.976 0.024]
#  [1.    0.   ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 8/10 -
# dual value optim :  10.781491747356784
# dual gradient theta :  0.0003437066045513592
# dual gradient eta :  0.1574418504299402
# KL Divergence:  1.1639501399621346e-10
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.976 0.024]
#  [1.    0.   ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 9/10 -
# dual value optim :  10.7752378019503
# dual gradient theta :  0.00042476666022458435
# dual gradient eta :  0.15733808326544452
# KL Divergence:  0.004425507656811996
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.989 0.011]
#  [1.    0.   ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 10/10 -
# dual value optim :  10.781491747356784
# dual gradient theta :  0.0003437066045513592
# dual gradient eta :  0.1574418504299402
# KL Divergence:  2.9960208604535776e-13
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5690544613687152
# Policy :
#  [[0.989 0.011]
#  [1.    0.   ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 1/10 -
# dual value optim :  6.076142335602796
# dual gradient theta :  0.3044552210692102
# dual gradient eta :  1.8030514530124035
# KL Divergence:  1.2429238777558271
# J: 9.67; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 2.011039010624579
# Policy :
#  [[0.627 0.373]
#  [0.68  0.32 ]
#  [0.936 0.064]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 2/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  0.04668145576101166
# J: 9.73; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.627 0.373]
#  [0.68  0.32 ]
#  [0.994 0.006]
#  [1.    0.   ]]
#
# #################################################
# Policy update 3/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  0.004083264749910286
# J: 9.69; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.627 0.373]
#  [0.68  0.32 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 4/10 -
# dual value optim :  10.773211853346773
# dual gradient theta :  0.0002694981764069721
# dual gradient eta :  0.14770471777645966
# KL Divergence:  0.1967558529935202
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.766 0.234]
#  [0.91  0.09 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 5/10 -
# dual value optim :  10.776371256233674
# dual gradient theta :  0.000268956895797602
# dual gradient eta :  0.14770208933464168
# KL Divergence:  0.07248610959522706
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.865 0.135]
#  [0.98  0.02 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 6/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  2.4953037424675163e-06
# J: 9.77; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.865 0.135]
#  [0.98  0.02 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 7/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  2.1149012670030532e-07
# J: 9.81; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.865 0.135]
#  [0.98  0.02 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 8/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  1.792486549887984e-08
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.865 0.135]
#  [0.98  0.02 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 9/10 -
# dual value optim :  10.782645332874406
# dual gradient theta :  0.0002077574155911684
# dual gradient eta :  0.1477791768331551
# KL Divergence:  1.5192234754072567e-09
# J: 9.81; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.865 0.135]
#  [0.98  0.02 ]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 10/10 -
# dual value optim :  10.776371256233674
# dual gradient theta :  0.000268956895797602
# dual gradient eta :  0.14770208933464168
# KL Divergence:  0.02789262610311892
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5714547197018438
# Policy :
#  [[0.926 0.074]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 1/10 -
# dual value optim :  5.302480782074138
# dual gradient theta :  0.31904128803855714
# dual gradient eta :  2.0496604218253482
# KL Divergence:  1.016052739748362
# J: 9.60; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 2.0170050981801015
# Policy :
#  [[0.598 0.402]
#  [0.588 0.412]
#  [0.865 0.135]
#  [0.999 0.001]]
#
# #################################################
#
# Policy update 2/10 -
# dual value optim :  10.782262487421455
# dual gradient theta :  0.00012046694241227484
# dual gradient eta :  0.1507306653062992
# KL Divergence:  0.08100092993963584
# J: 9.62; b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.598 0.402]
#  [0.588 0.412]
#  [0.978 0.022]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 3/10 -
# dual value optim :  10.77598183286316
# dual gradient theta :  0.00016464250384548983
# dual gradient eta :  0.1506801472461623
# KL Divergence:  0.17487060633478532
# J: 9.77; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.712 0.288]
#  [0.828 0.172]
#  [0.997 0.003]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 4/10 -
# dual value optim :  10.782262487421455
# dual gradient theta :  0.00012046694241227484
# dual gradient eta :  0.1507306653062992
# KL Divergence:  0.0019023536650986895
# J: 9.73; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.712 0.288]
#  [0.828 0.172]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 5/10 -
# dual value optim :  10.77598183286316
# dual gradient theta :  0.00016464250384548983
# dual gradient eta :  0.1506801472461623
# KL Divergence:  0.08136381626489216
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.805 0.195]
#  [0.942 0.058]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 6/10 -
# dual value optim :  10.77598183286316
# dual gradient theta :  0.00016464250384548983
# dual gradient eta :  0.1506801472461623
# KL Divergence:  0.036248696655056235
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.873 0.127]
#  [0.982 0.018]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 7/10 -
# dual value optim :  10.782262487421455
# dual gradient theta :  0.00012046694241227484
# dual gradient eta :  0.1507306653062992
# KL Divergence:  5.905108750682946e-06
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.873 0.127]
#  [0.982 0.018]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 8/10 -
# dual value optim :  10.782262487421455
# dual gradient theta :  0.00012046694241227484
# dual gradient eta :  0.1507306653062992
# KL Divergence:  8.606670762065323e-07
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.873 0.127]
#  [0.982 0.018]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 9/10 -
# dual value optim :  10.782262487421455
# dual gradient theta :  0.00012046694241227484
# dual gradient eta :  0.1507306653062992
# KL Divergence:  1.2544112158408823e-07
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.873 0.127]
#  [0.982 0.018]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 10/10 -
# dual value optim :  10.77598183286316
# dual gradient theta :  0.00016464250384548983
# dual gradient eta :  0.1506801472461623
# KL Divergence:  0.017234530023396775
# J: 9.77; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.570740006270054
# Policy :
#  [[0.92  0.08 ]
#  [0.995 0.005]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 1/10 -
# dual value optim :  6.078921916511993
# dual gradient theta :  0.47274568864899563
# dual gradient eta :  1.776334741054952
# KL Divergence:  1.5418152810024508
# J: 9.73; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.9706962163688448
# Policy :
#  [[0.663 0.337]
#  [0.796 0.204]
#  [0.983 0.017]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 2/10 -
# dual value optim :  10.778963816936024
# dual gradient theta :  0.0006423034070674515
# dual gradient eta :  0.12733042639638814
# KL Divergence:  0.21132789211431943
# J: 9.76; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.821 0.179]
#  [0.97  0.03 ]
#  [0.999 0.001]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 3/10 -
# dual value optim :  10.778963816936024
# dual gradient theta :  0.0006423034070674515
# dual gradient eta :  0.12733042639638814
# KL Divergence:  0.054696484924551245
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 4/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  1.6098541917587262e-05
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
# Policy update 5/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  5.380416576679888e-07
# J: 9.80; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 6/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  1.7982440272488097e-08
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 7/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  6.010099615295769e-10
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 8/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  2.00869693040783e-11
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 9/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  6.71326761037841e-13
# J: 9.79; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
#
# #################################################
#
# Policy update 10/10 -
# dual value optim :  10.78523473331831
# dual gradient theta :  0.0005375475260948906
# dual gradient eta :  0.1274629374383771
# KL Divergence:  2.2547263872892435e-14
# J: 9.78; b'ABNORMAL_TERMINATION_IN_LNSRCH'
# eta is: 1.5764491759955628
# Policy :
#  [[0.914 0.086]
#  [0.996 0.004]
#  [1.    0.   ]
#  [1.    0.   ]]
# ---SARSA_Means----
# [1.082 1.16  1.144 1.294 1.161 1.18  1.076 1.132 1.07  1.105]
# 10
# ---REPS_Means---
# [9.666 9.728 9.758 9.773 9.787 9.778 9.796 9.787 9.799 9.787]
# 10
# ---REINFORCE_Means---
# [1.115 1.581 3.081 6.391 7.358 8.62  9.098 9.153 9.201 9.301]
# 10
# ---REINFORCE+IS+Causality_Means---
# [5.128 5.623 6.813 8.789 7.51  8.632 8.688 8.528 8.704 8.598]
# 10
