# %% [markdown]
# # 598RL Project Workspace

# %%
import gym.spaces#import basic packages
from IPython import display
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import gym.spaces
import gym
import FastSLAM

params_ = {}
import gym.spaces
env = gym.make('FastSLAM-v0')
# Out:
# /home/akshay_shetty160992/.local/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
state = env.reset()
env.render_world()
# env.render_obs_fixedLM()

# %%
state
# Out:
# array([1000., 1000., 1000., 1000., 1000., 1000.,    1.,    0.])

# %%
# env.reward_type = 'Covariance'
r_ = []
yaw_ = []
while env.time < 10.0:

#     action = np.random.normal(0.0, np.deg2rad(2.0))
    state, r, terminal, info = env.step(np.deg2rad(10.0))
#     state, r, terminal, info = env.step(0.0)
    r_.append(r)
    env.render_world()
#     env.render_obs()
#     env.render_obs_fixedLM()
    yaw_.append(info["estimated"][2].item(0))
    display.clear_output(wait=True)
    plt.pause(0.001)
    print(state)
# Out:
# [-6.86053516e-01 -4.84936869e-01 -7.88268713e-01 -4.48147170e-01
#   1.00000000e+03  1.00000000e+03  3.42020143e-01 -9.39692621e-01]

# %%
# plt.plot(np.rad2deg(yaw_))
plt.plot(r_)
sum(r_)
# Out:
# 64.0

# %%
import numpy as np

# %%
# asd = np.ones(10)*10
asd = np.array([4,2,3,6,9,1,7])
qwe = np.argsort(asd)
print(asd)
print(qwe)
tmp = np.array([0,0,0,0,0,0,0])
for i in range(asd.shape[0]):
    tmp[i] = asd[qwe[i]]
print(tmp)
