# %% [markdown]
# # 598RL Project Workspace

# %%
import gym.spaces#import basic packages
from IPython import display
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import gym.spaces
import gym
import FastSLAM

params_ = {}
import gym.spaces
env = gym.make('FastSLAM-v0')

# %%
init_state = env.reset()
env.render_world()
env.render_obs_fixedLM()

# %%
env.reward_type = 'Covariance'
r_ = []
while env.time <= 10.0:

    action = np.random.normal(0.0, np.deg2rad(2.0))
#     state, r, terminal, info = env.step(action)
    state, r, terminal, info = env.step(0.0)
    r_.append(r)
    env.render_world()
#     env.render_obs()
    display.clear_output(wait=True)
    plt.pause(0.001)

# %%
asd = np.ones(( 1, 2 ))
qwe = np.asarray([1.0,1.0])[None,:]
print(asd==qwe)
# Out:
# [[ True  True]]

# %%
plt.plot(r_)

# %%
init_state.shape
# Out:
# (13,)
