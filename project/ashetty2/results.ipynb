# %% [markdown]
# # 598RL Project Workspace

# %%
#import basic packages
from IPython import display
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import gym.spaces
import gym
import FastSLAM

params_ = {}
env = gym.make('FastSLAM-v0')

# %%
init_state = env.reset()
env.render_world()

# %%
# init_state = env.reset()
while env.time <= 10.0:

    action = np.random.normal(0.0, np.deg2rad(2.0))
    state, r, terminal, info = env.step(action)
    print(r)
    env.render_world()
#     env.render_obs()
    display.clear_output(wait=True)
    plt.pause(0.001)

# %%
# avg_pos_err, avg_yaw_err = [], []
# avg_pos_errDR, avg_yaw_errDR = [], []
# for i in range(100):

#     asd = env.reset()
#     pos_err, yaw_err = [], []
#     pos_errDR, yaw_errDR = [], []
#     while env.time <= 5.0:

#         info = env.step(0.0)
#         pos_err.append(np.linalg.norm((info["estimated"]-info["true"])[0:2]))
#         yaw_err.append(np.abs((info["estimated"]-info["true"])[2]))
#         pos_errDR.append(np.linalg.norm((info["dead_reckoning"]-info["true"])[0:2]))
#         yaw_errDR.append(np.abs((info["dead_reckoning"]-info["true"])[2]))
                
# #         env.render()
#         display.clear_output(wait=True)
#         print(i)
# #         plt.pause(0.001)
            
#     avg_pos_err.append(np.mean(pos_err))
#     avg_yaw_err.append(np.mean(yaw_err))
#     avg_pos_errDR.append(np.mean(pos_errDR))
#     avg_yaw_errDR.append(np.mean(yaw_errDR))
    
# plt.plot(avg_pos_err)
# plt.plot(avg_pos_errDR)
# plt.show()
# plt.plot(avg_yaw_err)
# plt.plot(avg_yaw_errDR)
# plt.show()

# %%
# print(np.mean(avg_pos_err), np.mean(avg_pos_errDR))
# print(np.mean(avg_yaw_err), np.mean(avg_yaw_errDR))
